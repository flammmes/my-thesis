# %%
# %store -r f1
# %store -r f2

# %%
f1
f1.columns = ['Ridge', 'SVM','Forest','Voting','ANN',"Beal",'Kouzel']
f1.plot()
plt.rcParams['figure.figsize'] = (15, 8)
plt.xlabel('random state')
plt.ylabel("AARE")
# Out:
# Text(0, 0.5, 'AARE')

# %%
f2
f2.columns = ['Ridge', 'SVM','Forest','Voting','ANN',"Almehaideb",'DC']
f2.plot()
plt.xlabel('random state')
plt.ylabel("AARE")
plt.rcParams['figure.figsize'] = (15, 8)

# %%
f11 = pd.DataFrame([f1['Voting'],f1['Beal']]).transpose()

# %%
f11.plot()
# Out:
# <AxesSubplot:>

# %%
f1.describe()
# Out:
#             Ridge         SVM      Forest      Voting         ANN        Beal  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     3.556958    3.466727    3.571943    3.429525    3.491173    3.541671
# std      0.297035    0.303297    0.271568    0.289886    0.326233    0.307766
# min      2.917980    2.771535    2.930589    2.780624    2.791557    2.820778
# 25%      3.384043    3.262003    3.396904    3.237764    3.273830    3.343037
# 50%      3.507067    3.425163    3.520138    3.388523    3.480472    3.554935
# 75%      3.689102    3.647764    3.731070    3.586817    3.703533    3.731454
# max      4.467903    4.267091    4.250866    4.195030    4.192869    4.383220
#
#            Kouzel
# count  100.000000
# mean     4.076434
# std      0.327409
# min      3.411190
# 25%      3.873526
# 50%      4.077633
# 75%      4.257682
# max      4.814845

# %%
f2.describe()
# Out:
#             Ridge         SVM      Forest      Voting         ANN  Almehaideb  \
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean     3.559215    3.417294    3.433946    3.354779    3.426481    6.740501
# std      0.292276    0.306363    0.285231    0.299283    0.335411    0.645631
# min      2.922339    2.751877    2.805521    2.673681    2.751071    5.401151
# 25%      3.345265    3.196201    3.241548    3.137442    3.191062    6.301572
# 50%      3.550478    3.389754    3.391274    3.344907    3.408879    6.649537
# 75%      3.706151    3.599709    3.589618    3.512691    3.595259    7.133182
# max      4.360721    4.219728    4.197646    4.173815    4.336612    8.424750
#
#               DC
# count  87.000000
# mean    7.149090
# std     0.803291
# min     5.101517
# 25%     6.771293
# 50%     7.198187
# 75%     7.603934
# max     9.068173

# %%
k = f2.Voting-f1.Beal

# %%
len(k[k<0])
# Out:
# 82
